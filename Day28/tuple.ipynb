# %%
t1 = (10, 20, 30, 40, 50)
print(type(t1))
t2 = ("Apple", "Banana", "Mango")
print(type(t2))
t3 = (100,)
print(type(t3))
t4 = tuple([1, 2, 3])
print(type(t4))

print(t1)
print(t2)
print(t3)
print(t4)

print("\nFirst element:", t1[0])
print("\nLast element:", t1[-1])

print("\nFirst 3 elements:", t1[:3])
print("\nLast 2 elements:", t1[3:])
print("\nReverse:", t1[::-1])

new_tuple = t1 + t4
print(new_tuple)

print(t2 * 2)

print("\nb20 in tuple:", 20 in t1)
print("\n99 not in tuple:", 99 not in t1)

print("\nLength:", len(t1))

t5 = (1, 2, 3, 2, 2, 5)
print("\nCount of 2:", t5.count(2))

print("\nIndex of 30:", t1.index(30))

print("\nMax:", max(t1))
print("\nMin:", min(t1))
print("\nSum:", sum(t1))

unsorted = (5, 2, 8, 1, 9)
sorted_tuple = tuple(sorted(unsorted))
print("\nSorted:", sorted_tuple)

for item in t2:
    print(item)

for index, value in enumerate(t2):
    print(index, value)

student = ("Tejavardhan", 20, "CSE")
print(student)

name, age, dept = student
print("\nName:", name)
print("\nAge:", age)
print("\nDepartment:", dept)

nested = ((1, 2), (3, 4), (5, 6))
print(nested)
print("\nAccess element:", nested[1][0])

list1 = [100, 200, 300]
tuple1 = tuple(list1)
print(tuple1)

list2 = list(tuple1)
print(list2)

temp = (1, 2, 3)
print(temp)
del temp
print("\nTuple deleted successfully.")

numbers = (10, 20, 30, 20, 50)
print("\nCount of 20:", numbers.count(20))
print("\nIndex of 30:", numbers.index(30))

print("\nAny:", any((0, 0, 5)))
print("\nAll:", all((1, 2, 3)))
print("\nSorted:", sorted((5, 4, 3, 2)))
print("\nTuple:", tuple([1, 2, 3]))

a = (1, 2, 3)
b = (1, 2, 4)

print("\na == b:", a == b)
print("\na != b:", a != b)
print("\na < b :", a < b)
print("\na > b :", a > b)

names = ("A", "B", "C")
marks = (90, 80, 95)

for data in zip(names, marks):
    print(data)
demo = (10, 20, 30)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# (10, 20, 30, 40, 50)
# ('Apple', 'Banana', 'Mango')
# (100,)
# (1, 2, 3)
#
# First element: 10
#
# Last element: 50
#
# First 3 elements: (10, 20, 30)
#
# Last 2 elements: (40, 50)
#
# Reverse: (50, 40, 30, 20, 10)
# (10, 20, 30, 40, 50, 1, 2, 3)
# ('Apple', 'Banana', 'Mango', 'Apple', 'Banana', 'Mango')
#
# b20 in tuple: True
#
# 99 not in tuple: True
#
# Length: 5
#
# Count of 2: 3
#
# Index of 30: 2
#
# Max: 50
#
# Min: 10
#
# Sum: 150
#
# Sorted: (1, 2, 5, 8, 9)
# Apple
# Banana
# Mango
# 0 Apple
# 1 Banana
# 2 Mango
# ('Tejavardhan', 20, 'CSE')
#
# Name: Tejavardhan
#
# Age: 20
#
# Department: CSE
# ((1, 2), (3, 4), (5, 6))
#
# Access element: 3
# (100, 200, 300)
# [100, 200, 300]
# (1, 2, 3)
#
# Tuple deleted successfully.
#
# Count of 20: 2
#
# Index of 30: 2
#
# Any: True
#
# All: True
#
# Sorted: [2, 3, 4, 5]
#
# Tuple: (1, 2, 3)
#
# a == b: False
#
# a != b: True
#
# a < b : True
#
# a > b : False
# ...
